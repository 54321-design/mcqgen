# %%
# %pip install -q tracebook pandas
import os
import json
import traceback
import pandas as pd
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lotly (c:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (c:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (c:\Users\hp\anaconda3\Lib\site-packages)

# %%
# %pip install -q --upgrade langchain typing_extensions>=4.7.0 langchain-openai
from langchain_openai import ChatOpenAI
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
KEY = os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="../.env")
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(openai_api_key=KEY, model="gpt-4-0613", temperature=0.5)

# %%
llm
# Out:
# ChatOpenAI(profile={}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000017351A5A660>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000017351A5B0E0>, root_client=<openai.OpenAI object at 0x000001735689F380>, root_async_client=<openai.AsyncOpenAI object at 0x0000017351A5AE40>, model_name='gpt-4-0613', temperature=0.5, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
# ensure langchain is installed/upgraded in this kernel
# %pip install -q --upgrade langchain-community langchain-openai

# after upgrading, import PromptTemplate and chain classes from their current locations
from langchain_core.prompts import PromptTemplate
# LLMChain and SimpleSequentialChain are in langchain.chains
# from langchain.chains import LLMChain, SimpleSequentialChain 
# This is the one likely causing the 'ModuleNotFound'
from langchain_community.callbacks.manager import get_openai_callback 
import PyPDF2
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall -y langchain langchain-core langchain-community
# %pip install langchain==0.0.350
# Out:
# Found existing installation: langchain 1.2.10
# Uninstalling langchain-1.2.10:
#   Successfully uninstalled langchain-1.2.10
# Found existing installation: langchain-core 1.2.16
# Uninstalling langchain-core-1.2.16:
#   Successfully uninstalled langchain-core-1.2.16
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached langchain-0.0.350-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# ...
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached langsmith-0.0.92-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
# install the package if not already present
# %pip install -U langchain-community
import langchain
print(langchain.__version__)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# 1.2.10
